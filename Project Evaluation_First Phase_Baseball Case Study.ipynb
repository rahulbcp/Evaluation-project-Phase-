# %% [markdown]
# ## Baseball Case Study
#
# ### Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# #### Input features-
# - 1) W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# - 2) R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# - 3) AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# - 4) H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# - 5) 2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# - 6) 3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# - 7) HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# - 8) BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# - 9) SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# - 10) SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# - 11) RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# - 12) ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# - 13) ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# - 14) CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# - 15) SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# - 16) SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# - 17) E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# ### -- Output: Number of predicted wins (W)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Admin\OneDrive\Desktop\Flip lobo\Project Evaluation\First Phase\baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# ##### Observation:
# - 1) All columns are having continuous data.
# - 2) Let's check data shape (row and column)

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# ##### Observation:
# - 1) Dataset having 30 rows and 17 columns.
# - 2) Out of 17 columns; 16 are features and 1 is target variable (Column = "W")
# - 3) All features and Target are continuous data.
# - 4) This is Regression Problem (considering target variable as continuous data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# ##### Observation:
# - 1) No null value found
# - 2) All features and target varibale are integer, except one feature (ERA) is float data.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# ##### Observation:
# - Its confirmed data having no null values.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# #### Observation:
# - Its's confirmed all features and target having integer data, except one column (ERA) having float data

# %%
## Check duplicate data
df1 = df[df.duplicated()]
df1
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# #### Observation:
# - No duplicate value found

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# #### Observation:
# - Its confirmed data having no null values
# - Can see high standard deviations in following features (R, AB, H, BB, SO, RA, and ER).
# - Can see outlier and skewness in some of the feature, will confirm same with graphs

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# - List of columns of dataset, which includes 16 features and 1 target variable (W)

# %%
## Checking the unique values in each column
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# #### Observations:
# - Can see lots of unique value in each features and target.

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# #### Osbervations:
# - Can see right skewness in the following features (R, H, HR, CG, SHO, SV, and E)
# - Will confirm with plot analysis

# %%
## Check distribution of data in all columns
plotnumber = 1
plt.figure(figsize = (10, 30))
for i in df.columns:
    if plotnumber <=18:
        plt.subplot(9, 2, plotnumber)
        sns.distplot(df[i], kde = True)
        plt.xlabel(i, fontsize = 20)
        plt.grid(axis='both')               
    plotnumber+=1  
plt.tight_layout()

# %% [markdown]
# #### Obersvations:
# - Its confirmed right skewness in the following features (R, H, HR, CG, SHO, SV, and E). Will check outliers.
# - Rest all features almost seems normally distibuted.

# %%
### Let's check Outliers
plt.figure(figsize = (10, 30))
number = 1
for col in df.columns:
    if number <= 18:
        plt.subplot(9, 2, number)
        sns.boxplot(data = df[col], orient = 'v')
        plt.xlabel(col)        
    number+=1
plt.tight_layout()

# %% [markdown]
# #### Observations:
# Following features having outliers (R, ERA, SHO, SV, and E)

# %%
## Check realtion betweeen features and target 
x = df.drop(['W'], axis=1)
y = df['W']

# %%
plotnumber = 1
plt.figure(figsize = (10, 30))
for i in x.columns:
    if plotnumber <=16:
        plt.subplot(8, 2, plotnumber)
        sns.regplot(x=i, y=y, data=df)
        plt.xlabel(i, fontsize = 15)
        plt.ylabel('W', fontsize = 15)
        plt.title(f'{i} vs Label', fontsize = 20)
        plt.grid(axis='both')
    plotnumber+=1 
plt.tight_layout()

# %% [markdown]
# #### Observation:
# - All features showing relation with target.
# - However, following features (RA, ERA, ER) having strong -ve relation with Target.
# - Feature SV having strong +ve relation with Target
# - Will get more clarity with further plotting analysis.

# %%
cor = df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %% [markdown]
# #### Observations:
# - Let's check with heatmap for more clarity on the same.

# %%
plt.figure(figsize = (20,10))
sns.heatmap(cor, annot=True, annot_kws={'size':12})
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observations:
# - Most of the features having relation with target variable, postively and negative
# - Following feature (SV) having strong +ve relation with target variable, like we seen in distplot.
# - Following features (ERA, ER, RA) having strong -ve relation with target variable, like we seen in distplot
# - Also, following features having very strong +ve multicollinearity - RA vs ERA, RA vs ER, and ER vs ERA.
# - Will select best feature for further analysis.

# %%
## removing outliers with z score
from scipy.stats import zscore
z = np.abs(zscore(df))
np.where(z>3)
df2 = df[(z<3).all(axis=1)]
old_data = df.shape[0]
new_data = df2.shape[0]
loss_data = ((old_data - new_data) / old_data) * 100
print('Old data =', old_data)
print('New data = ', new_data)
print('Loss data in percentage = ', loss_data)
# Out:
# Old data = 30
# New data =  29
# Loss data in percentage =  3.3333333333333335

# %% [markdown]
# #### Observation:
# - Seems outlier's have been removed, will check again with dist plot after removing skewness.

# %%
df = df2 ### Transfer into original dataframe

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# #### Osbervations
# - Can see skewness has been resolved of 'R'
# - Further skewness will be dealt

# %%
# Let's handle skewness of following features. Will try first with Cuberoot.
Feature_1 = ['H', 'CG', 'SHO', 'SV'] ## will check with Cuberoot
Feature_2 = ['E', 'CG'] ## will check with Box-cox transformation.

# %%
df[Feature_1] = np.cbrt(df[Feature_1])
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.753696
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -1.013981
# SHO   -0.298136
# SV     0.280963
# E      0.840271
# dtype: float64

# %% [markdown]
# ### Observations:
# - Can we skewness resolved for following features ('SHO' and 'SV')
# - Will handle other features skewness with Box-Cox Transformation.

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method = 'box-cox', standardize=False)

# %%
df[Feature_2] = scaler.fit_transform(df[Feature_2]+2)

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.753696
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.143954
# SHO   -0.298136
# SV     0.280963
# E      0.066012
# dtype: float64

# %% [markdown]
# #### Observations:
# - Skewness has been resolved for almost all features.
# - Let's reconfirm with distplot

# %%
## Check distribution of data in all columns after handling skewness
plotnumber = 1
plt.figure(figsize = (10, 30))
for i in df.columns:
    if plotnumber <=18:
        plt.subplot(9, 2, plotnumber)
        sns.distplot(df[i], kde = True)
        plt.xlabel(i, fontsize = 20)
        plt.grid(axis='both')               
    plotnumber+=1  
plt.tight_layout()

# %% [markdown]
# #### Observations:
# - Can see almost normally distributed in all features, which confirmed no skewness as well, except column [H].

# %%
x = df.drop(['W'], axis=1)
y = df['W']

# %% [markdown]
# #### Obervations:
# - Split Target and Variables for further standarization.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x1 = pd.DataFrame(x_scaled, columns = x.columns)
x1
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0
# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
best_features = SelectKBest(score_func=f_classif, k=16)
fit = best_features.fit(x,y)
df_scores = pd.DataFrame(fit.scores_)
df_columns = pd.DataFrame(x.columns)
features_scores = pd.concat([df_columns, df_scores], axis=1)
features_scores.columns = ['Feature_Name', 'Score']
print(features_scores.nlargest(16,'Score'))
# Out:
#    Feature_Name     Score
# 15            E  4.329167
# 8            SB  3.283197
# 9            RA  2.524616
# 0             R  2.485509
# 14           SV  2.190896
# 11          ERA  1.732208
# 10           ER  1.636442
# 1            AB  1.622586
# 7            SO  1.519889
# 6            BB  0.943327
# 13          SHO  0.903772
# 5            HR  0.818974
# 4            3B  0.811129
# 3            2B  0.799063
# 2             H  0.729214
# 12           CG  0.406889

# %% [markdown]
# #### Observations:
# - Basis observation of above plotting for relationship between features and target variable.
# - Along with Select K Best, features will be selected who have highest score.

# %%
final_selection = df.drop(['BB', 'SHO','HR', '2B', '3B', 'H', 'CG'], axis=1)
final_selection
x = final_selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
### Creating train test split
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.25, random_state = 300)

# %%
RFR = RandomForestRegressor()
ETR = ExtraTreesRegressor()
GBR = GradientBoostingRegressor()
ABR = AdaBoostRegressor()
BR =  BaggingRegressor()
LR = LinearRegression()
lasso = Lasso()
ridge = Ridge()
DTR = DecisionTreeRegressor()
KNR = KNeighborsRegressor()
svr = SVR()

# %%
def metric_score(model, x_train,x_test,y_train,y_test, train=True):
    if train:
        y_pred = model.predict(x_train)
        
        print(f"Model Name: {model_name}")
        print("\n---------------Train Result---------------")
        print('R2 score: ', r2_score(y_train, y_pred)*100)       
        print('Mean Absolute Error: ', mean_absolute_error(y_train, y_pred))
        print('Mean Squared Error: ', mean_squared_error(y_train, y_pred))
        print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_train, y_pred)))
    elif train==False:
        pred = model.predict(x_test)
        
        print("\n---------------Test Result---------------")
        print("R2 Score:  ", r2_score(y_test, pred)*100)
        print('Mean Absolute Error: ', mean_absolute_error(y_test, pred))
        print('Mean Squared Error: ', mean_squared_error(y_test, pred))
        print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test, pred)))
        print('\n')

# %%
models = [('RFR', RFR), ('ETR', ETR), ('GBR', GBR), ('ABR', ABR), ('BR', BR),  ('LR', LR), ('Lasso', lasso), ('Ridge', ridge), ('DTR', DTR), ('KNR', KNR), ('SVR', svr)]
for model_name, model in models:
    model.fit(x_train, y_train)

# %%
for model_name, model in models:
    metric_score(model, x_train,x_test,y_train,y_test, train=True)
    metric_score(model, x_train,x_test,y_train,y_test, train=False)
# Out:
# Model Name: RFR
#
# ---------------Train Result---------------
# R2 score:  98.10127329678934
# Mean Absolute Error:  0.8885714285714285
# Mean Squared Error:  1.6494380952380978
# Root Mean Squared Error:  1.2843045181101318
#
# ---------------Test Result---------------
# R2 Score:   88.065907960199
# Mean Absolute Error:  2.3187499999999996
# Mean Squared Error:  11.993762500000003
# Root Mean Squared Error:  3.4632011925384876
#
#
# Model Name: ETR
#
# ---------------Train Result---------------
# R2 score:  100.0
# Mean Absolute Error:  0.0
# Mean Squared Error:  0.0
# Root Mean Squared Error:  0.0
#
# ---------------Test Result---------------
# R2 Score:   94.54022388059701
# Mean Absolute Error:  1.5900000000000016
# Mean Squared Error:  5.48707500000001
# Root Mean Squared Error:  2.342450639821469
#
#
# Model Name: GBR
#
# ---------------Train Result---------------
# R2 score:  99.99999988888472
# Mean Absolute Error:  0.00024146694270264053
# Mean Squared Error:  9.652667754051607e-08
# Root Mean Squared Error:  0.00031068742739370075
#
# ---------------Test Result---------------
# R2 Score:   93.55922285782441
# Mean Absolute Error:  2.1539612155621253
# Mean Squared Error:  6.472981027886469
# Root Mean Squared Error:  2.544205382410482
#
#
# Model Name: ABR
#
# ---------------Train Result---------------
# R2 score:  99.69082391766418
# Mean Absolute Error:  0.3230158730158729
# Mean Squared Error:  0.26858357628765817
# Root Mean Squared Error:  0.5182504956945609
#
# ---------------Test Result---------------
# R2 Score:   91.13659998618022
# Mean Absolute Error:  2.451041666666667
# Mean Squared Error:  8.90771701388889
# Root Mean Squared Error:  2.9845798722582195
#
#
# Model Name: BR
#
# ---------------Train Result---------------
# R2 score:  95.36969459671104
# Mean Absolute Error:  1.4619047619047614
# Mean Squared Error:  4.022380952380955
# Root Mean Squared Error:  2.0055874332426784
#
# ---------------Test Result---------------
# R2 Score:   78.65422885572139
# Mean Absolute Error:  3.7750000000000004
# Mean Squared Error:  21.452500000000008
# Root Mean Squared Error:  4.631684358848302
#
#
# Model Name: LR
#
# ---------------Train Result---------------
# R2 score:  100.0
# Mean Absolute Error:  2.4699818909755864e-14
# Mean Squared Error:  8.29430894632378e-28
# Root Mean Squared Error:  2.879984192026717e-14
#
# ---------------Test Result---------------
# R2 Score:   100.0
# Mean Absolute Error:  3.730349362740526e-14
# Mean Squared Error:  1.8427790745962836e-27
# Root Mean Squared Error:  4.2927602711964753e-14
#
#
# Model Name: Lasso
#
# ---------------Train Result---------------
# R2 score:  99.95033570273864
# Mean Absolute Error:  0.17516688813323186
# Mean Squared Error:  0.0431437466685456
# Root Mean Squared Error:  0.20771072834243684
#
# ---------------Test Result---------------
# R2 Score:   99.87989483467618
# Mean Absolute Error:  0.3008800775763856
# Mean Squared Error:  0.12070569115043184
# Root Mean Squared Error:  0.3474272458377895
#
#
# Model Name: Ridge
#
# ---------------Train Result---------------
# R2 score:  99.9997848039348
# Mean Absolute Error:  0.01095952922897782
# Mean Squared Error:  0.0001869424321543163
# Root Mean Squared Error:  0.01367268928025194
#
# ---------------Test Result---------------
# R2 Score:   99.99925469526684
# Mean Absolute Error:  0.022554747441128953
# Mean Squared Error:  0.0007490312568129551
# Root Mean Squared Error:  0.027368435410394857
#
#
# Model Name: DTR
#
# ---------------Train Result---------------
# R2 score:  100.0
# Mean Absolute Error:  0.0
# Mean Squared Error:  0.0
# Root Mean Squared Error:  0.0
#
# ---------------Test Result---------------
# R2 Score:   80.4726368159204
# Mean Absolute Error:  3.375
# Mean Squared Error:  19.625
# Root Mean Squared Error:  4.430011286667337
#
#
# Model Name: KNR
#
# ---------------Train Result---------------
# R2 score:  57.95395458104933
# Mean Absolute Error:  5.085714285714285
# Mean Squared Error:  36.52571428571429
# Root Mean Squared Error:  6.043650741539776
#
# ---------------Test Result---------------
# R2 Score:   -12.199004975124407
# Mean Absolute Error:  9.450000000000001
# Mean Squared Error:  112.76000000000002
# Root Mean Squared Error:  10.618851161966628
#
#
# Model Name: SVR
#
# ---------------Train Result---------------
# R2 score:  -0.40142278700567857
# Mean Absolute Error:  7.753356893295141
# Mean Squared Error:  87.21946727823554
# Root Mean Squared Error:  9.339136323998892
#
# ---------------Test Result---------------
# R2 Score:   -55.623734842390164
# Mean Absolute Error:  10.487937875882354
# Mean Squared Error:  156.4018535166021
# Root Mean Squared Error:  12.506072665573397

# %% [markdown]
# ### Observations:
# - Considering following metric scores (R2, MAE, MSE, RSME) on both train and test data, three models (LR, Lasso, and Ridge) can be selected because they all have highest R2 score with less MAE, MSE, and RSME.
# - Let's check if they are overfitting to the model.

# %%
from sklearn.model_selection import cross_val_score

# %%
for model_name, model in models:
    score = cross_val_score(model, x, y, cv=10)
    print(f"Model Name: {model_name}")
    print('R2 Score = ',r2_score(y_test, model.predict(x_test))*100)
    print('Cross validation score = ', score.mean()* 100)
    print('Difference between R2 Score and Cross Validation Score = ', r2_score(y_test, model.predict(x_test)) - score.mean())
    print('\n')
# Out:
# Model Name: RFR
# R2 Score =  88.065907960199
# Cross validation score =  70.04115348727206
# Difference between R2 Score and Cross Validation Score =  0.1802475447292694
#
#
# Model Name: ETR
# R2 Score =  94.54022388059701
# Cross validation score =  48.00610075902153
# Difference between R2 Score and Cross Validation Score =  0.46534123121575477
#
#
# Model Name: GBR
# R2 Score =  93.55922285782441
# Cross validation score =  53.63095231575704
# Difference between R2 Score and Cross Validation Score =  0.3992827054206737
#
#
# Model Name: ABR
# R2 Score =  91.13659998618022
# Cross validation score =  41.360869562376685
# Difference between R2 Score and Cross Validation Score =  0.49775730423803527
#
#
# Model Name: BR
# R2 Score =  78.65422885572139
# Cross validation score =  47.94290521645291
# Difference between R2 Score and Cross Validation Score =  0.3071132363926848
#
#
# Model Name: LR
# R2 Score =  100.0
# Cross validation score =  100.0
# Difference between R2 Score and Cross Validation Score =  0.0
#
#
# Model Name: Lasso
# R2 Score =  99.87989483467618
# Cross validation score =  99.11329986910637
# Difference between R2 Score and Cross Validation Score =  0.007665949655698112
#
#
# Model Name: Ridge
# R2 Score =  99.99925469526684
# Cross validation score =  99.99707409015545
# Difference between R2 Score and Cross Validation Score =  2.180605111390399e-05
#
#
# Model Name: DTR
# R2 Score =  80.4726368159204
# Cross validation score =  -47.17645369252899
# Difference between R2 Score and Cross Validation Score =  1.276490905084494
#
#
# Model Name: KNR
# R2 Score =  -12.199004975124407
# Cross validation score =  -593.3282719885643
# Difference between R2 Score and Cross Validation Score =  5.811292670134399
#
#
# Model Name: SVR
# R2 Score =  -55.623734842390164
# Cross validation score =  -680.6198602498258
# Difference between R2 Score and Cross Validation Score =  6.249961254074356

# %% [markdown]
# #### Observations:
# - The LR (Linear Regression) model seems to have a perfect fit on both training and test data, along with a perfect cross-validation score. This might imply overfitting, especially when achieving 100% on both training and test sets.
# - Lasso and Ridge Regression models also exhibit extremely high performance but with slightly lower scores compared to the LR model. Ridge seems to have a very marginal edge over Lasso, but the difference is negligible.
# - However, considering slight difference between Lasson and Ridge, Ridge can be finalized as best model

# %%
## Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# %%
base_regressor = Ridge()
param_grid = {'alpha': [1.0, 0.05, 0.4, 2],
              'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'],
              'random_state': list(range(100, 300, 10)),
              'fit_intercept': [True, False],              
             }

# %%
gridsearch = GridSearchCV(base_regressor, param_grid, cv=5)
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'random_state': [100, 110, 120, 130, 140, 150, 160,
#                                           170, 180, 190, 200, 210, 220, 230,
#                                           240, 250, 260, 270, 280, 290],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga', 'lbfgs']})

# %%
gridsearch.best_estimator_
# Out:
# Ridge(alpha=0.05, fit_intercept=False, random_state=100)

# %%
gridsearch.best_score_
# Out:
# 0.9999999087313018

# %%
Final_model = Lasso(alpha=0.05, fit_intercept=False, random_state=100)
Final_model.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.05, fit_intercept=False, random_state=100)

# %%
y_pred = Final_model.predict(x_train)
print("\n---------------Train Result---------------")
print('R2 score: ', r2_score(y_train, y_pred)*100)
pred = Final_model.predict(x_test)
print("\n---------------Test Result---------------")
print("R2 Score:  ", r2_score(y_test, pred)*100)
print('Mean Absolute Error: ', mean_absolute_error(y_test, pred))
print('Mean Squared Error: ', mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(y_test, pred)))
print('\n')
# Out:
# ---------------Train Result---------------
# R2 score:  99.99999998419914
#
# ---------------Test Result---------------
# R2 Score:   99.999999948562
# Mean Absolute Error:  0.00019706401467090018
# Mean Squared Error:  5.169517210441001e-08
# Root Mean Squared Error:  0.00022736572323991583

# %% [markdown]
# #### Observations:
# - No much difference seen, as we already reached almost 100% R2 Score

# %%
### Plotting to check relation betweeen y_test and y_pred
sns.regplot(x=y_test, y= pred)
# Out:
# <AxesSubplot:xlabel='W'>

# %% [markdown]
# #### Observation:
# - Can be uniform distribution between y_test and y_pred

# %% [markdown]
# #### Saving the final model

# %%
import pickle

# %%
pickle.dump(Final_model, open('Baseball Case Study','wb'))

# %%
## Do the predication
loaded_model = pickle.load(open('Baseball Case Study','rb'))
predicted = loaded_model.predict(x_test)
original = np.array(y_test)
df = pd.DataFrame()
df['Predicted'] = predicted
df['Original'] = original
df
# Out:
#    Predicted  Original
# 0  81.000003        81
# 1  89.999812        90
# 2  99.999593       100
# 3  68.000182        68
# 4  84.999853        85
# 5  91.999751        92
# 6  97.999710        98
# 7  78.000112        78

# %% [markdown]
# #### Observation:
# - Can see model is predicting almost like original dataset

# %%
print("R2 Score:  ", r2_score(y_test, predicted)*100)
# Out:
# R2 Score:   99.999999948562

# %% [markdown]
# ### Observations:
# - Can see R2 score as 99.99% (almost 100%)
